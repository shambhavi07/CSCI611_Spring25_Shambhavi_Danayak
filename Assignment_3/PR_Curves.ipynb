# %% [markdown]
# ### Run with image resolution= 640 and batch size =16

# %%
import matplotlib.pyplot as plt
import cv2

pr_curve_path = "runs/detect/train/PR_curve.png"
image = cv2.imread(pr_curve_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  

plt.figure(figsize=(8,6))
plt.imshow(image)
plt.axis("off")  
plt.title("Precision-Recall Curve")
plt.show()

# %% [markdown]
# ### Run with high image resolution

# %%
import matplotlib.pyplot as plt
import cv2

pr_curve_path = "runs_high_Reso/exp_highres/PR_curve.png"
image = cv2.imread(pr_curve_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  

plt.figure(figsize=(8,6))
plt.imshow(image)
plt.axis("off")  
plt.title("Precision-Recall Curve")
plt.show()

# %% [markdown]
# ### Run with Data augmentation arguments

# %%
import matplotlib.pyplot as plt
import cv2

pr_curve_path = "runs_Data_aug_scale/exp_dataAug_scale/PR_curve.png"
image = cv2.imread(pr_curve_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  

plt.figure(figsize=(8,6))
plt.imshow(image)
plt.axis("off")  
plt.title("Precision-Recall Curve")
plt.show()

# %% [markdown]
# ### Run with Anchor box tuning

# %%
import matplotlib.pyplot as plt
import cv2

pr_curve_path = "runs_Data_aug_scale_withAnchorBoxTuning/exp_dataAug_scale_withAnchorBoxTuning/PR_curve.png"
image = cv2.imread(pr_curve_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  

plt.figure(figsize=(8,6))
plt.imshow(image)
plt.axis("off")  
plt.title("Precision-Recall Curve")
plt.show()
